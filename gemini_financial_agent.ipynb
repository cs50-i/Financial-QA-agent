# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Install required packages
try:
    from langchain_community.vectorstores import Chroma
    from langchain_community.embeddings import HuggingFaceEmbeddings
    from langchain_text_splitters import RecursiveCharacterTextSplitter
    from langchain_core.documents import Document
    from langgraph.graph import StateGraph, END
    from langchain_community.document_loaders import PyPDFLoader
    import google.generativeai as genai
except ImportError:
    print("Installing required packages...")
    # !pip install langchain-core==0.1.0 langchain-community==0.0.10 chromadb==0.4.15 langgraph==0.0.40 sentence-transformers torch transformers pypdf google-generativeai
    from langchain_community.vectorstores import Chroma
    from langchain_community.embeddings import HuggingFaceEmbeddings
    from langchain_text_splitters import RecursiveCharacterTextSplitter
    from langchain_core.documents import Document
    from langgraph.graph import StateGraph, END
    from langchain_community.document_loaders import PyPDFLoader
    import google.generativeai as genai

from typing import Dict, List, Any, TypedDict
import glob

class GeminiFinancialQASystem:
    """Financial Q&A System using Gemini 2.5 Flash"""
    
    def __init__(self, data_path: str = 'Financial-QA-10k.csv'):
        self.vectorstore = None
        self.gemini_model = None
        self.graph = None
        self.data_path = data_path
        self._initialize_system()
    
    def _initialize_system(self):
        """Initialize system with Gemini"""
        print("🚀 Initializing Gemini Financial Q&A System...")
        
        # 1. Initialize Gemini
        self._initialize_gemini()
        
        # 2. Load and prepare data
        documents = self._prepare_documents()
        
        # 3. Initialize vector store
        self.vectorstore = self._initialize_vector_store(documents)
        
        # 4. Build graph
        self.graph = self._build_graph()
        
        print("✅ Gemini Financial Q&A System initialized successfully!")
    
    def _initialize_gemini(self):
        """Initialize Gemini 2.5 Flash"""
        print("🔧 Initializing Gemini 2.5 Flash...")
        
        try:
            # Configure Gemini - you need to set GOOGLE_API_KEY environment variable
            api_key = os.getenv('GOOGLE_API_KEY')
            if not api_key:
                print("❌ GOOGLE_API_KEY not found. Please set it as environment variable.")
                raise ValueError("GOOGLE_API_KEY environment variable is required")
            
            genai.configure(api_key=api_key)
            
            # Initialize Gemini 2.5 Flash model
            self.gemini_model = genai.GenerativeModel('gemini-2.0-flash')
            
            # Test the connection
            response = self.gemini_model.generate_content("Hello, please respond with 'OK' to confirm connection.")
            if "OK" in response.text:
                print("✅ Gemini 2.5 Flash connected successfully!")
            else:
                print(f"✅ Gemini 2.5 Flash connected. Response: {response.text}")
                
        except Exception as e:
            print(f"❌ Gemini initialization failed: {e}")
            raise
    
    def _prepare_documents(self) -> List[Document]:
        """Prepare documents from CSV data"""
        print("📊 Loading financial dataset...")
        
        try:
            df = pd.read_csv(self.data_path)
            df = df.fillna('')
            print(f"✅ Loaded {len(df)} Q&A pairs")
            
            documents = []
            for idx, row in df.iterrows():
                # Create structured content
                content = f"""
QUESTION: {row['question']}
ANSWER: {row['answer']}
CONTEXT: {row['context']}
COMPANY: {row['ticker']}
FILING_YEAR: {row['filing']}
"""
                
                metadata = {
                    "ticker": row['ticker'],
                    "filing_year": row['filing'],
                    "source": "qa_database",
                    "original_question": row['question'],
                    "original_answer": row['answer'],
                    "document_type": "financial_qa"
                }
                
                documents.append(Document(page_content=content, metadata=metadata))
            
            return documents
            
        except Exception as e:
            print(f"❌ Error loading data: {e}")
            return []
    
    def _initialize_vector_store(self, documents: List[Document]) -> Chroma:
        """Initialize vector store"""
        print("🔧 Initializing vector store...")
        
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            chunk_overlap=150,
        )
        
        splits = text_splitter.split_documents(documents)
        print(f"📄 Created {len(splits)} document chunks")
        
        embeddings = HuggingFaceEmbeddings(
            model_name="sentence-transformers/all-MiniLM-L6-v2",
            model_kwargs={'device': 'cpu'}
        )
        
        vectorstore = Chroma.from_documents(
            documents=splits,
            embedding=embeddings,
            persist_directory="./gemini_financial_qa_db"
        )
        
        return vectorstore
    
    def add_pdfs(self, pdf_directory: str) -> int:
        """Add PDF documents to the knowledge base"""
        print(f"📥 Adding PDFs from: {pdf_directory}")
        
        pdf_files = glob.glob(os.path.join(pdf_directory, "*.pdf"))
        if not pdf_files:
            print("❌ No PDF files found")
            return 0
        
        all_documents = []
        
        for pdf_file in pdf_files:
            try:
                print(f"📄 Processing: {os.path.basename(pdf_file)}")
                
                loader = PyPDFLoader(pdf_file)
                documents = loader.load()
                
                for doc in documents:
                    doc.metadata.update({
                        "source_file": os.path.basename(pdf_file),
                        "source_type": "pdf_filing",
                        "document_type": "10K"
                    })
                
                text_splitter = RecursiveCharacterTextSplitter(
                    chunk_size=1200,
                    chunk_overlap=200
                )
                split_docs = text_splitter.split_documents(documents)
                all_documents.extend(split_docs)
                
                print(f"✅ Added {len(split_docs)} chunks from {os.path.basename(pdf_file)}")
                
            except Exception as e:
                print(f"❌ Error processing {pdf_file}: {e}")
        
        if all_documents:
            self.vectorstore.add_documents(all_documents)
            print(f"📊 Successfully added {len(all_documents)} PDF document chunks")
        
        return len(all_documents)
    
    def _build_graph(self):
        """Build LangGraph workflow with Gemini"""
        
        def retrieve_node(state: Dict) -> Dict:
            """Retrieve relevant documents"""
            print("🔍 Retrieving relevant financial information...")
            
            question = state["question"]
            
            try:
                # Enhanced retrieval with more documents for better context
                docs = self.vectorstore.similarity_search(question, k=6)
                
                context = []
                sources = []
                
                for doc in docs:
                    source_type = doc.metadata.get("source", "unknown")
                    if source_type == "qa_database":
                        source_info = f"Q&A Database - {doc.metadata.get('ticker', 'Unknown')}"
                    elif source_type == "pdf_filing":
                        source_info = f"PDF Filing - {doc.metadata.get('source_file', 'Unknown')}"
                    else:
                        source_info = "Financial Document"
                    
                    context.append({
                        "content": doc.page_content,
                        "metadata": doc.metadata,
                        "source_info": source_info
                    })
                    sources.append(source_info)
                
                state["context"] = context
                state["sources"] = list(set(sources))
                print(f"✅ Retrieved {len(context)} relevant documents")
                
            except Exception as e:
                print(f"❌ Retrieval error: {e}")
                state["context"] = []
                state["sources"] = []
            
            return state
        
        def generate_node(state: Dict) -> Dict:
            """Generate answers using Gemini"""
            print("🤖 Generating answer with Gemini...")
            
            question = state["question"]
            context = state["context"]
            
            try:
                if not context:
                    state["answer"] = "I couldn't find relevant information to answer this question in the available financial documents."
                    return state
                
                # Build comprehensive context
                context_text = self._build_gemini_context(context)
                
                # Generate with Gemini
                answer = self._generate_with_gemini(question, context_text)
                
                state["answer"] = answer
                print("✅ Answer generated successfully")
                
            except Exception as e:
                print(f"❌ Generation error: {e}")
                state["answer"] = self._create_fallback_answer(context)
            
            return state
        
        def evaluate_node(state: Dict) -> Dict:
            """Evaluate the response quality"""
            answer = state["answer"]
            context = state["context"]
            
            evaluation = []
            
            # Answer length evaluation
            word_count = len(answer.split())
            if word_count > 100:
                evaluation.append("✅ Comprehensive analysis")
            elif word_count > 50:
                evaluation.append("✅ Detailed answer")
            elif word_count > 20:
                evaluation.append("✅ Adequate answer")
            else:
                evaluation.append("⚠️ Brief answer")
            
            # Source utilization
            if len(context) >= 4:
                evaluation.append("✅ Excellent context usage")
            elif len(context) >= 2:
                evaluation.append("✅ Good context usage")
            else:
                evaluation.append("⚠️ Limited context")
            
            # Financial content check
            financial_terms = ['revenue', 'income', 'profit', 'growth', 'margin', 'cash', 'debt', 
                              'equity', 'assets', 'risk', 'segment', 'investment', 'market']
            financial_count = sum(1 for term in financial_terms if term in answer.lower())
            
            if financial_count >= 3:
                evaluation.append("✅ Strong financial analysis")
            elif financial_count >= 1:
                evaluation.append("✅ Financial content present")
            else:
                evaluation.append("⚠️ Limited financial depth")
            
            state["evaluation"] = " | ".join(evaluation)
            return state
        
        # Build the graph
        workflow = StateGraph(Dict)
        workflow.add_node("retrieve", retrieve_node)
        workflow.add_node("generate", generate_node)
        workflow.add_node("evaluate", evaluate_node)
        
        workflow.set_entry_point("retrieve")
        workflow.add_edge("retrieve", "generate")
        workflow.add_edge("generate", "evaluate")
        workflow.add_edge("evaluate", END)
        
        return workflow.compile()
    
    def _build_gemini_context(self, context: List[Dict]) -> str:
        """Build context optimized for Gemini"""
        context_parts = []
        
        for i, doc in enumerate(context):
            content = doc["content"]
            metadata = doc["metadata"]
            source_info = doc["source_info"]
            
            # Format for Gemini
            context_parts.append(f"--- SOURCE {i+1} ({source_info}) ---\n{content}\n")
        
        return "\n".join(context_parts)
    
    def _generate_with_gemini(self, question: str, context: str) -> str:
        """Generate answer using Gemini 2.5 Flash"""
        
        prompt = f"""You are a senior financial analyst specializing in SEC filings and corporate financial analysis. 

Based EXCLUSIVELY on the following information from financial documents, 10-K filings, and Q&A data, provide a comprehensive and accurate answer to the question.

FINANCIAL DOCUMENTS AND CONTEXT:
{context}

QUESTION: {question}

ANALYSIS REQUIREMENTS:
1. Answer based SOLELY on the provided financial context
2. Be specific, detailed, and factually accurate
3. Include relevant numbers, dates, metrics, and financial data when available
4. Cite the specific sources when referencing information
5. If certain information is not available in the context, acknowledge this limitation
6. Structure complex answers with clear sections or bullet points
7. Use professional financial terminology and analysis frameworks
8. Highlight trends, comparisons, or significant findings when relevant

RESPONSE FORMAT:
- Start with a direct, concise answer
- Provide supporting evidence and details from the sources
- Mention specific companies, years, and metrics when available
- Use bullet points for multiple items or comparisons
- Conclude with any limitations or additional context needed

FINANCIAL ANALYST'S COMPREHENSIVE ANSWER:"""

        try:
            # Generate with Gemini
            response = self.gemini_model.generate_content(
                prompt,
                generation_config=genai.types.GenerationConfig(
                    temperature=0.2,  # Low temperature for factual accuracy
                    top_p=0.8,
                    top_k=40,
                    max_output_tokens=2000,  # Allow detailed responses
                )
            )
            
            return response.text.strip()
            
        except Exception as e:
            print(f"❌ Gemini generation error: {e}")
            return self._create_fallback_answer_from_context(context)
    
    def _create_fallback_answer(self, context: List[Dict]) -> str:
        """Create fallback answer from context"""
        if not context:
            return "I don't have enough information to answer this question based on the available financial documents."
        
        # Extract key information from context
        key_info = []
        for doc in context[:3]:  # Use first 3 documents
            content = doc["content"]
            # Try to extract answer from Q&A format
            if "ANSWER:" in content:
                answer_part = content.split("ANSWER:")[1]
                if "CONTEXT:" in answer_part:
                    answer_part = answer_part.split("CONTEXT:")[0]
                key_info.append(answer_part.strip())
            else:
                key_info.append(content[:300] + "...")
        
        return f"Based on the financial documents:\n\n" + "\n\n".join(key_info)
    
    def _create_fallback_answer_from_context(self, context: str) -> str:
        """Create fallback answer from context string"""
        lines = context.split('\n')
        relevant_lines = [line for line in lines if len(line.strip()) > 10]
        
        if relevant_lines:
            return "Based on the financial information available:\n\n" + "\n".join(relevant_lines[:8])
        else:
            return "The financial documents contain relevant information, but I'm unable to generate a comprehensive analysis at the moment."
    
    def query(self, question: str, verbose: bool = True) -> Dict[str, Any]:
        """Query the Gemini-powered system"""
        if verbose:
            print(f"\n🎯 QUESTION: {question}")
            print("=" * 70)
        
        initial_state = {
            "question": question,
            "context": [],
            "answer": "",
            "evaluation": "",
            "sources": []
        }
        
        try:
            result = self.graph.invoke(initial_state)
            
            if verbose:
                print(f"\n📝 ANSWER:\n{result['answer']}")
                print(f"\n📊 EVALUATION: {result['evaluation']}")
                
                if result["sources"]:
                    print(f"\n🔗 SOURCES:")
                    for i, source in enumerate(result["sources"][:5], 1):
                        print(f"   {i}. {source}")
                
                print(f"\n📈 CONTEXT UTILIZATION: {len(result['context'])} documents retrieved")
            
            return result
            
        except Exception as e:
            error_msg = f"Pipeline execution error: {e}"
            print(f"❌ {error_msg}")
            return {
                "question": question,
                "answer": "I encountered an error while processing your question. Please try again.",
                "evaluation": "System error",
                "sources": [],
                "error": error_msg
            }

# Advanced financial analysis capabilities
class FinancialAnalyzer:
    """Advanced financial analysis using Gemini"""
    
    def __init__(self, qa_system: GeminiFinancialQASystem):
        self.qa_system = qa_system
    
    def compare_companies(self, companies: List[str], aspect: str) -> Dict[str, Any]:
        """Compare multiple companies on specific aspects"""
        question = f"Compare {', '.join(companies)} in terms of {aspect}. Provide specific financial metrics, trends, and strategic differences from their 10-K filings and financial reports."
        return self.qa_system.query(question)
    
    def analyze_trends(self, company: str, metric: str, years: List[str] = None) -> Dict[str, Any]:
        """Analyze financial trends for a company"""
        year_context = f" from {years[0]} to {years[-1]}" if years else " over recent years"
        question = f"Analyze the {metric} trends for {company}{year_context}. Include specific numbers, growth rates, and key drivers mentioned in their financial filings."
        return self.qa_system.query(question)
    
    def risk_analysis(self, company: str) -> Dict[str, Any]:
        """Comprehensive risk analysis"""
        question = f"Provide a comprehensive risk analysis for {company} based on their 10-K filings. Include operational risks, financial risks, market risks, and strategic risks with specific examples from their reports."
        return self.qa_system.query(question)
    
    def business_segment_analysis(self, company: str) -> Dict[str, Any]:
        """Analyze business segments and revenue breakdown"""
        question = f"Analyze the business segments and revenue breakdown for {company}. Provide specific revenue numbers, growth rates by segment, and strategic importance of each segment from their latest financial reports."
        return self.qa_system.query(question)

# Demonstration and testing
def demonstrate_gemini_system():
    """Comprehensive demonstration of Gemini-powered system"""
    print("=" * 80)
    print("🌟 GEMINI-POWERED FINANCIAL Q&A SYSTEM")
    print("=" * 80)
    
    # Check for API key
    if not os.getenv('GOOGLE_API_KEY'):
        print("❌ GOOGLE_API_KEY environment variable not set!")
        print("💡 Please set it first:")
        print("   import os")
        print("   os.environ['GOOGLE_API_KEY'] = 'your_actual_api_key'")
        print("💡 Get free API key from: https://aistudio.google.com/app/apikey")
        return
    
    # Initialize system
    qa_system = GeminiFinancialQASystem()
    analyzer = FinancialAnalyzer(qa_system)
    
    # Test questions
    test_scenarios = [
        {
            "category": "Company History & Focus",
            "questions": [
                "What was NVIDIA's initial business focus and how has it evolved over time?",
                "What significant technological inventions did NVIDIA create and when?",
                "How does NVIDIA describe its transformation from graphics to AI computing?"
            ]
        },
        {
            "category": "Financial Performance", 
            "questions": [
                "What are NVIDIA's main revenue drivers and business segments?",
                "How has NVIDIA's revenue composition changed in recent years?",
                "What are the key financial metrics that demonstrate NVIDIA's growth?"
            ]
        },
        {
            "category": "Technology & Products",
            "questions": [
                "What is CUDA and what computational capabilities does it enable?",
                "What are the main applications of NVIDIA's GPU technology beyond gaming?",
                "How does NVIDIA's platform strategy integrate hardware and software?"
            ]
        }
    ]
    
    print("\n🧪 RUNNING COMPREHENSIVE TESTS:")
    for scenario in test_scenarios:
        print(f"\n📊 CATEGORY: {scenario['category']}")
        print("-" * 60)
        
        for question in scenario["questions"]:
            result = qa_system.query(question)
            print("\n" + "=" * 70)
    
    # Test PDF integration
    print(f"\n📄 TESTING PDF INTEGRATION:")
    pdf_dir = "./10k_pdfs"
    if os.path.exists(pdf_dir) and any(f.endswith('.pdf') for f in os.listdir(pdf_dir)):
        print(f"📥 Adding PDFs from {pdf_dir}")
        added_count = qa_system.add_pdfs(pdf_dir)
        
        if added_count > 0:
            print(f"\n🔬 ADVANCED ANALYSIS WITH PDFS:")
            
            # Advanced analysis with PDFs
            advanced_questions = [
                "What is NVIDIA's current revenue breakdown by business segment?",
                "What are the major risk factors discussed in NVIDIA's latest 10-K filing?",
                "How does NVIDIA describe its competitive advantages and market position?",
                "What is the company's strategy for future growth and investment?",
                "what are in the products in the iphone line?",
            ]
            
            for question in advanced_questions:
                print(f"\n🎯 {question}")
                result = qa_system.query(question, verbose=False)
                print(f"📝 {result['answer'][:300]}...")
                print(f"📊 {result['evaluation']}")
                print(f"🔗 Sources: {result['sources']}")
                print("-" * 50)
    
    # Demonstrate advanced analysis
    print(f"\n🔬 ADVANCED FINANCIAL ANALYSIS DEMONSTRATION:")
    
    return qa_system

# Interactive chat interface
def interactive_gemini_chat():
    """Interactive chat with Gemini-powered system"""
    print("\n💬 GEMINI FINANCIAL Q&A CHAT")
    print("Type 'quit' to exit, 'sources' to show recent sources\n")
    
    # Check for API key
    if not os.getenv('GOOGLE_API_KEY'):
        print("❌ GOOGLE_API_KEY not set. Please set it first.")
        return
    
    qa_system = GeminiFinancialQASystem()
    
    # Add PDFs if available
    pdf_dir = "./10k_pdfs"
    if os.path.exists(pdf_dir) and any(f.endswith('.pdf') for f in os.listdir(pdf_dir)):
        print("📥 Loading PDF documents...")
        qa_system.add_pdfs(pdf_dir)
    
    chat_history = []
    
    while True:
        question = input("\n❓ Your financial question: ").strip()
        
        if question.lower() in ['quit', 'exit', 'bye']:
            print("👋 Thank you for using the Gemini Financial Q&A System!")
            break
        elif question.lower() == 'sources':
            print("\n📚 Recent sources mentioned:")
            for i, source in enumerate(set([s for chat in chat_history for s in chat.get('sources', [])]), 1):
                print(f"  {i}. {source}")
            continue
        elif not question:
            continue
        
        print("\n" + "🔄 Processing with Gemini..." + "\n")
        result = qa_system.query(question)
        
        # Store in history
        chat_history.append(result)
        
        print(f"\n💡 Tip: Ask about:")
        print("   - Company financials and performance")
        print("   - Technology and product strategies") 
        print("   - Risk factors and market analysis")
        print("   - Business segments and revenue breakdown")


if __name__ == "__main__":    
    # Check if API key is available
    if os.getenv('GOOGLE_API_KEY'):
        # Run demonstration
        demonstrate_gemini_system()
        
        # Start interactive chat
        chat_option = input("\n💬 Start interactive chat? (y/n): ").strip().lower()
        if chat_option in ['y', 'yes']:
            interactive_gemini_chat()
    else:
        print("\n❌ Please set GOOGLE_API_KEY environment variable first.")
        print("💡 Use the setup instructions above to get your free API key.")
# Out:
# ================================================================================
# 🌟 GEMINI-POWERED FINANCIAL Q&A SYSTEM
# ================================================================================
# 🚀 Initializing Gemini Financial Q&A System...
# 🔧 Initializing Gemini 2.5 Flash...
# ✅ Gemini 2.5 Flash connected successfully!
# 📊 Loading financial dataset...
# ✅ Loaded 7000 Q&A pairs
# 🔧 Initializing vector store...
# 📄 Created 7338 document chunks
# ✅ Gemini Financial Q&A System initialized successfully!
#
# 🧪 RUNNING COMPREHENSIVE TESTS:
#
# 📊 CATEGORY: Company History & Focus
# ------------------------------------------------------------
#
# 🎯 QUESTION: What was NVIDIA's initial business focus and how has it evolved over time?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# NVIDIA's initial business focus was on PC graphics. Since then, the company has expanded into other computationally intensive fields.
#
# **Supporting Evidence and Details:**
#
# *   **Initial Focus:** According to the provided Q&A data from NVIDIA's 2023 10-K filings, NVIDIA "initially focused on PC graphics" (SOURCE 1, SOURCE 2, SOURCE 3, SOURCE 4, SOURCE 5, SOURCE 6).
# *   **Expansion:** The context provided in each source indicates that "Since our original focus on PC graphics, we have expanded to several other large and important computationally intensive fields" (SOURCE 1, SOURCE 2, SOURCE 3, SOURCE 4, SOURCE 5, SOURCE 6).
#
# **Limitations:**
#
# *   The specific computationally intensive fields NVIDIA expanded into are not detailed in the provided context.
# *   Specific dates or timelines of this expansion are not provided.
# *   Financial metrics related to the impact of this expansion are not included.
#
# **Additional Context Needed:**
#
# To provide a more comprehensive analysis, additional information is needed regarding the specific computationally intensive fields NVIDIA expanded into, the timeline of this expansion, and the financial impact of these new ventures.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ⚠️ Limited financial depth
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 🎯 QUESTION: What significant technological inventions did NVIDIA create and when?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# NVIDIA invented the GPU (Graphics Processing Unit) in 1999. This invention defined modern computer graphics and established NVIDIA as a leader in the field.
#
# Supporting Evidence:
#
# *   **Invention:** NVIDIA invented the GPU in 1999 (Source 1, 2, 3, 4, 5, 6).
# *   **Significance:** This invention defined modern computer graphics and established NVIDIA as a leader in computer graphics (Source 1, 2, 3, 4, 5, 6).
# *   **Source:** This information is consistently reported across multiple Q&A entries related to NVIDIA's 2023 10-K filing (Source 1, 2, 3, 4, 5, 6).
#
# Limitations:
#
# *   The provided context is limited to NVIDIA's invention of the GPU in 1999. It does not provide information on other technological inventions by NVIDIA or details about the financial impact of the GPU invention.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ⚠️ Limited financial depth
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 🎯 QUESTION: How does NVIDIA describe its transformation from graphics to AI computing?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# NVIDIA leveraged its GPU architecture to create platforms for scientific computing, AI, data science, AV, robotics, metaverse, and 3D internet applications, thereby pivoting beyond PC graphics.
#
# **Supporting Evidence and Details:**
#
# *   **Core Strategy:** NVIDIA leveraged its GPU architecture to expand into new markets (Source 1, 2, 3, 4, 5, 6).
# *   **Target Applications:** The company created platforms specifically for scientific computing, AI, data science, AV (autonomous vehicles), robotics, metaverse, and 3D internet applications (Source 1, 2, 3, 4, 5, 6).
# *   **Driving Force:** This pivot was fueled by the sustained demand for exceptional 3D graphics and the scale of the gaming market (Source 1, 2, 3, 4, 5, 6).
# *   **Filing Year:** This strategy is documented in the 2023 10-K filings (Source 1, 2, 3, 4, 5, 6).
#
# **Limitations:**
#
# The provided context does not include specific financial metrics (e.g., revenue breakdown by segment, R&D spending on AI vs. graphics) to quantify the impact of this transformation. Additional information would be needed to assess the financial success and strategic implications of this pivot in greater detail.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Strong financial analysis
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 📊 CATEGORY: Financial Performance
# ------------------------------------------------------------
#
# 🎯 QUESTION: What are NVIDIA's main revenue drivers and business segments?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# NVIDIA's revenue is primarily driven by sales in the United States, Taiwan, and China (including Hong Kong), as well as other countries. The company's revenue is designated based on the billing location of the customer, which may differ from the end customer location (Source 1, 2, 3, 4, 5, 6).
#
# **Supporting Evidence and Details:**
#
# *   **Revenue by Geographic Area:**
#     *   **United States:** Revenue increased significantly from $4,349 million in the year ended January 30, 2022, to $8,292 million in the year ended January 29, 2023, and further to $26,966 million in the year ended January 28, 2024 (Source 1, 2, 3, 4, 5, 6).
#     *   **Taiwan:** Revenue decreased from $8,544 million in the year ended January 30, 2022, to $6,986 million in the year ended January 29, 2023, and then increased to $13,405 million in the year ended January 28, 2024 (Source 1, 2, 3, 4, 5, 6).
#     *   **China (including Hong Kong):** Revenue decreased from $7,111 million in the year ended January 30, 2022, to $5,785 million in the year ended January 29, 2023, and then increased to $10,306 million in the year ended January 28, 2024 (Source 1, 2, 3, 4, 5, 6).
#     *   **Other Countries:** Revenue increased from $6,910 million in the year ended January 30, 2022, to $5,911 million in the year ended January 29, 2023, and then increased to $10,245 million in the year ended January 28, 2024 (Source 1, 2, 3, 4, 5, 6).
#     *   **Total Revenue:** Total revenue increased from $26,914 million in the year ended January 30, 2022, to $26,974 million in the year ended January 29, 2023, and significantly increased to $60,922 million in the year ended January 28, 2024 (Source 1, 2, 3, 4, 5, 6).
#
# *   **Reconciling Items:**
#     *   Stock-based compensation expense was $(3,549) million for the year ended January 28, 2024, $(2,710) million for the year ended January 29, 2023, and $(2,004) million for the year ended January 30, 2022 (Source 1, 2, 3, 4, 5, 6).
#     *   Acquisition termination cost was $(1,353) million for the year ended January 29, 2023 (Source 1, 2, 3, 4, 5, 6).
#
# **Limitations and Additional Context Needed:**
#
# The provided financial documents focus primarily on revenue by geographic area and reconciling items included in the "All Other" category. To fully understand NVIDIA's main revenue drivers and business segments, additional information is needed, such as:
#
# *   **Revenue by Product/Service Category:** Data on revenue generated by different product lines (e.g., GPUs, data center solutions, gaming products, automotive).
# *   **Cost of Revenue and Gross Profit by Segment:** Information on the profitability of each business segment.
# *   **Operating Expenses by Segment:** Details on R&D, marketing, and administrative expenses allocated to each segment.
# *   **Market Share Data:** Analysis of NVIDIA's market position in each of its key markets.
# *   **Macroeconomic Factors:** Discussion of how global economic conditions and industry trends impact NVIDIA's revenue.
# *   **Specific Customer Information:** While billing location is provided, understanding the end customer industries (e.g., cloud providers, automotive manufacturers, gaming companies) would be beneficial.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Strong financial analysis
#
# 🔗 SOURCES:
#    1. Financial Document
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 🎯 QUESTION: How has NVIDIA's revenue composition changed in recent years?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# Based on the provided information, I cannot determine how NVIDIA's revenue composition has changed in recent years. The provided data focuses exclusively on the typical seasonal variation of NVIDIA's product revenue.
#
# Here's a breakdown of what *is* known from the provided sources:
#
# *   **Seasonal Revenue Pattern:** NVIDIA's product revenue typically experiences stronger sales in the second half of its fiscal year (Sources 1-6).
# *   **Specific Quarterly Strengths:** The second and third quarters tend to be particularly strong for products related to notebooks and game consoles (Sources 1-6).
# *   **Specific Quarterly Weaknesses:** The fourth and first quarters tend to be weaker revenue periods (Sources 1-6).
# *   **Consumer Products:** NVIDIA's consumer products generally see stronger revenue in the second half of the fiscal year (Sources 1-6).
# *   **Fiscal Year:** The data is based on the 2023 10-K filing (Sources 1-6).
#
# **Limitations:**
#
# The provided information does not include any data on:
#
# *   Specific revenue figures for any product categories.
# *   Historical revenue data to compare changes over time.
# *   Breakdown of revenue by geographic region or customer type.
# *   Information on other revenue streams besides product revenue.
#
# Therefore, I cannot provide any insights into how NVIDIA's revenue composition has changed in recent years based solely on the provided context.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Financial content present
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 🎯 QUESTION: What are the key financial metrics that demonstrate NVIDIA's growth?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# Based solely on the provided information, I cannot answer the question "What are the key financial metrics that demonstrate NVIDIA's growth?". The provided context focuses exclusively on the seasonality of NVIDIA's product revenue and does not contain any information about key financial metrics or growth indicators.
#
# The provided data from NVIDIA's 2023 10-K filings (Sources 1-6) consistently states the following regarding NVIDIA's product revenue seasonality:
#
# *   **General Trend:** NVIDIA's product revenue typically sees stronger sales in the second half of the fiscal year (Sources 1-6).
# *   **Specific Products:** Products for notebooks and game consoles typically generate stronger revenue in the second and third quarters (Sources 1-6).
# *   **Weaker Periods:** Revenue is typically weaker in the fourth and first quarters (Sources 1-6).
# *   **Consumer Products:** Consumer products typically see stronger revenue in the second half of the fiscal year (Sources 1-6).
#
# **Limitations:**
#
# The provided context is limited to the seasonality of NVIDIA's product revenue. It does not include any specific financial metrics (e.g., revenue growth rate, net income, earnings per share, gross margin) that would be necessary to demonstrate NVIDIA's growth. Therefore, I cannot answer the question about key financial metrics demonstrating NVIDIA's growth based on the provided information.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Strong financial analysis
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 📊 CATEGORY: Technology & Products
# ------------------------------------------------------------
#
# 🎯 QUESTION: What is CUDA and what computational capabilities does it enable?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# NVIDIA's CUDA programming model opened the parallel processing capabilities of GPUs for general purpose computing.
#
# **Supporting Evidence and Details:**
#
# *   **CUDA's Function:** According to multiple sources from NVIDIA's 2023 10-K filings, the CUDA programming model opened the parallel processing capabilities of NVIDIA's GPUs for general purpose computing (Source 1, Source 2, Source 3, Source 4, Source 5, Source 6).
# *   **Introduction Year:** NVIDIA introduced the CUDA programming model in 2006 (Source 1, Source 2, Source 3, Source 4, Source 5, Source 6).
#
# **Limitations:**
#
# The provided context is limited to the function and introduction year of NVIDIA's CUDA programming model. Further information regarding the specific computational capabilities enabled, the financial impact of CUDA, or its competitive landscape is not available within the provided sources.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ⚠️ Limited financial depth
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 🎯 QUESTION: What are the main applications of NVIDIA's GPU technology beyond gaming?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# NVIDIA expanded the application of its GPU architecture beyond PC graphics by leveraging it to create platforms for scientific computing, AI, data science, AV (Autonomous Vehicles), robotics, metaverse, and 3D internet applications.
#
# **Supporting Evidence and Details:**
#
# *   **Core Strategy:** NVIDIA leveraged its existing GPU architecture, initially driven by the demand for 3D graphics and the gaming market, to expand into new areas (Sources 1, 2, 3, 4, 5, 6).
# *   **Specific Applications:** The specific applications of NVIDIA's GPU technology beyond gaming include:
#     *   Scientific computing
#     *   Artificial Intelligence (AI)
#     *   Data science
#     *   Autonomous Vehicles (AV)
#     *   Robotics
#     *   Metaverse applications
#     *   3D internet applications (Sources 1, 2, 3, 4, 5, 6).
# *   **Year:** This pivot and diversification are highlighted in the 2023 10-K filings (Sources 1, 2, 3, 4, 5, 6).
#
# **Limitations:**
#
# The provided context does not include specific financial data (revenue breakdowns, growth rates) related to each of these application areas. Therefore, a quantitative assessment of the success and relative importance of each application is not possible based solely on this information. Additional information would be needed to perform a more in-depth financial analysis.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Strong financial analysis
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 🎯 QUESTION: How does NVIDIA's platform strategy integrate hardware and software?
# ======================================================================
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
#
# 📝 ANSWER:
# Based on the provided information, NVIDIA's platform strategy integrates hardware and software by bringing them together along with systems, algorithms, libraries, and services to create unique value for the markets it serves.
#
# **Supporting Evidence and Details:**
#
# *   **Core Strategy:** NVIDIA's platform strategy is consistently described as a comprehensive approach that combines hardware, systems, software, algorithms, libraries, and services (Source 1, Source 2, Source 3, Source 4, Source 5, Source 6).
# *   **Value Creation:** The integration of these elements is specifically aimed at creating unique value for the markets NVIDIA serves (Source 1, Source 2, Source 3, Source 4, Source 5, Source 6).
# *   **Consistency Across Filings:** This description of NVIDIA's platform strategy is consistent across multiple entries from the 2023 10-K filings (FILING_YEAR: 2023_10K) (Source 1, Source 2, Source 3, Source 4, Source 5, Source 6).
#
# **Limitations and Additional Context Needed:**
#
# The provided context does not offer specific details on *how* the hardware and software are technically integrated. It only describes the *what* – that they are brought together. Further information would be needed to understand the specific engineering and architectural approaches used to achieve this integration. For example, details on specific software frameworks optimized for NVIDIA hardware, or hardware features designed to accelerate specific software algorithms, would provide a more complete picture.
#
# 📊 EVALUATION: ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Financial content present
#
# 🔗 SOURCES:
#    1. Q&A Database - NVDA
#
# 📈 CONTEXT UTILIZATION: 6 documents retrieved
#
# ======================================================================
#
# 📄 TESTING PDF INTEGRATION:
# 📥 Adding PDFs from ./10k_pdfs
# 📥 Adding PDFs from: ./10k_pdfs
# 📄 Processing: GOOG_2022_10K.pdf
# ✅ Added 345 chunks from GOOG_2022_10K.pdf
# 📄 Processing: AMD_2024_10K.pdf
# ✅ Added 462 chunks from AMD_2024_10K.pdf
# 📄 Processing: NVDA_2024_10K.pdf
# ✅ Added 367 chunks from NVDA_2024_10K.pdf
# 📄 Processing: AAPL_2023_10K.pdf
# ✅ Added 220 chunks from AAPL_2023_10K.pdf
# 📊 Successfully added 1394 PDF document chunks
#
# 🔬 ADVANCED ANALYSIS WITH PDFS:
#
# 🎯 What is NVIDIA's current revenue breakdown by business segment?
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
# 📝 Based solely on the provided financial documents, NVIDIA's revenue breakdown by business segment is *not* available. The provided data focuses on revenue by geographic area and reconciling items included in the "All Other" category. Therefore, a business segment revenue breakdown cannot be determine...
# 📊 ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Strong financial analysis
# 🔗 Sources: ['Financial Document']
# --------------------------------------------------
#
# 🎯 What are the major risk factors discussed in NVIDIA's latest 10-K filing?
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
# 📝 Based solely on the provided information, it is impossible to determine the major risk factors discussed in NVIDIA's latest 10-K filing. The provided text from the 10-K filings focuses on forward-looking statements, the definition of NVIDIA, and a general disclaimer regarding the uncertainty and lim...
# 📊 ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Financial content present
# 🔗 Sources: ['Financial Document']
# --------------------------------------------------
#
# 🎯 How does NVIDIA describe its competitive advantages and market position?
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
# 📝 Based on the provided information, I can only address how NVIDIA's platform strategy contributes to the markets it serves. I cannot address NVIDIA's competitive advantages and market position, as that information is not provided in the given context.
#
# **How NVIDIA's platform strategy contributes to ...
# 📊 ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Financial content present
# 🔗 Sources: ['Q&A Database - NVDA']
# --------------------------------------------------
#
# 🎯 What is the company's strategy for future growth and investment?
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
# 📝 Based on the provided information from the 2023 10-K filings and Q&A data for EFX, the company's strategy for future growth and investment involves continued investment in core areas and strategic acquisitions.
#
# **Details:**
#
# *   **Core Investments:** EFX plans to continue investing in the following...
# 📊 ✅ Comprehensive analysis | ✅ Excellent context usage | ✅ Strong financial analysis
# 🔗 Sources: ['Q&A Database - EFX']
# --------------------------------------------------
#
# 🎯 what are in the products in the iphone line?
# 🔍 Retrieving relevant financial information...
# ✅ Retrieved 6 relevant documents
# 🤖 Generating answer with Gemini...
# ✅ Answer generated successfully
# 📝 The iPhone line includes iPhone 15 Pro, iPhone 15, iPhone 14, iPhone 13 and iPhone SE.
#
# Supporting Evidence:
#
# *   **Source 1, 2, 3, 4, 5, 6:** "iPhone is the Company’s line of smartphones based on its iOS operating system. The iPhone line includes iPhone 15 Pro, iPhone 15, iPhone 14, iPhone 13 and i...
# 📊 ✅ Detailed answer | ✅ Excellent context usage | ⚠️ Limited financial depth
# 🔗 Sources: ['Financial Document']
# --------------------------------------------------
#
# 🔬 ADVANCED FINANCIAL ANALYSIS DEMONSTRATION:
#
# 💬 GEMINI FINANCIAL Q&A CHAT
# Type 'quit' to exit, 'sources' to show recent sources
#
# 🚀 Initializing Gemini Financial Q&A System...
# 🔧 Initializing Gemini 2.5 Flash...
# ✅ Gemini 2.5 Flash connected successfully!
# 📊 Loading financial dataset...
# ✅ Loaded 7000 Q&A pairs
# 🔧 Initializing vector store...
# 📄 Created 7338 document chunks
# ✅ Gemini Financial Q&A System initialized successfully!
# 📥 Loading PDF documents...
# 📥 Adding PDFs from: ./10k_pdfs
# 📄 Processing: GOOG_2022_10K.pdf
# ✅ Added 345 chunks from GOOG_2022_10K.pdf
# 📄 Processing: AMD_2024_10K.pdf
# ✅ Added 462 chunks from AMD_2024_10K.pdf
# 📄 Processing: NVDA_2024_10K.pdf
# ✅ Added 367 chunks from NVDA_2024_10K.pdf
# 📄 Processing: AAPL_2023_10K.pdf
# ✅ Added 220 chunks from AAPL_2023_10K.pdf
# 📊 Successfully added 1394 PDF document chunks
